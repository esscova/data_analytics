# %% [markdown]
# # Visualizando gráficos com Python

# %%
# bibliotecas
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# carregando dados
df = pd.read_csv('../datasets/trees.csv', sep=',', encoding='utf-8')
df.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Girth   31 non-null     float64
#  1   Height  31 non-null     int64
#  2   Volume  31 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 876.0 bytes

# %% [markdown]
# ## Histogramas

# %%
# obtendo dados do intervalo histograma com numpy
np.histogram(df.iloc[:,1], bins=6)
# Out:
# (array([4, 2, 5, 7, 9, 4]), array([63., 67., 71., 75., 79., 83., 87.]))

# %%
# plot com pandas
df.iloc[:,1].hist(bins=6)
# Out:
# <Axes: >

# %%
# Histograma 
df['Height'].plot(kind='hist', bins=10, alpha=0.7, color='skyblue', edgecolor='black')
plt.title('Distribuição das Alturas das Árvores')
plt.xlabel('Altura (metros)')
plt.ylabel('Frequência')
plt.show()

# %%
# plot com matplotlib
plt.hist(df['Height'], bins=6)
plt.title('Distribuição de Frequência')
plt.xlabel('Altura')
plt.ylabel('Frequência')
plt.show()

# %%
# plot com seaborn
sns.histplot(data=df['Height'], bins=6).set_title('Distribuição de Frequência')
plt.xlabel('Altura')
plt.ylabel('Frequência')
plt.show()

# %%
# seaborn com kde
sns.histplot(df['Height'], kde=True)
plt.title('Distribuição das Alturas das Árvores com KDE')
plt.xlabel('Altura (metros)')
plt.ylabel('Frequência')
plt.show()

# %%
# kde com suavização
sns.histplot(df['Height'], kde=True, kde_kws={'bw_adjust':0.5})
plt.title('Distribuição das Alturas das Árvores com KDE (bw_adjust=0.5)')
plt.xlabel('Altura (metros)')
plt.ylabel('Frequência')
plt.show()
