# %% [markdown]
# ## Gráficos utilizando R

# %% [markdown]
# descrição:
#
#     - Exemplos para fixação de prática com a linguagem R
#
# autor:
#
#     - wellington moreira
#     - wsantos08@hotmail.com
#
# environment:
#
#     - conda r-base
#     - R version 4.3.1 (2023-06-16)

# %% [markdown]
# ## carregando dados

# %%
# datasets
head(trees) 
head(CO2)
# Out:
#   Girth Height Volume
# 1  8.3  70     10.3
# 2  8.6  65     10.3
# 3  8.8  63     10.2
# 4 10.5  72     16.4
# 5 10.7  81     18.8
# 6 10.8  83     19.7
#   Plant Type   Treatment  conc uptake
# 1 Qn1   Quebec nonchilled  95  16.0
# 2 Qn1   Quebec nonchilled 175  30.4
# 3 Qn1   Quebec nonchilled 250  34.8
# 4 Qn1   Quebec nonchilled 350  37.2
# 5 Qn1   Quebec nonchilled 500  35.3
# 6 Qn1   Quebec nonchilled 675  39.2

# %% [markdown]
# ## gráficos

# %% [markdown]
# ### histograma

# %%
hist(trees$Height)
# Out:
# Plot with title “Histogram of trees$Height”

# %%
# adicionando personalizações
hist(trees$Height,
     main = "Distribuição das Alturas das Árvores",
     xlab = "Altura",
     ylab = "Frequência",
     col = "blue")
# Out:
# Plot with title “Distribuição das Alturas das Árvores”

# %%
# ajustando densidade e intervalos
hist(trees$Height,
     main = "Distribuição das Alturas",
     xlab = "Altura",
     ylab = "Frequência",
     col = "blue",
     density = 20,
     breaks = 20)
# Out:
# Plot with title “Distribuição das Alturas”

# %% [markdown]
# ### densidade

# %%
# calculo e plot
densidade <- density(trees$Height)
plot(densidade,
     main = 'Densidade da Altura das Árvores',
     xlab = 'Altura',
     ylab = 'Densidade')
# Out:
# Plot with title “Densidade da Altura das Árvores”

# %% [markdown]
# ### sobreposição: histograma e densidade

# %%
# histograma
hist(trees$Height, main=NULL, xlab=NULL, ylab=NULL)
par(new = TRUE)
# densidade
plot(densidade, col='red', lwd=2, main='Histograma com Densidade')
# Out:
# Plot with title “Histograma com Densidade”

# %% [markdown]
# ### dispersão

# %%
# circunferencia x volume
plot(trees$Girth, trees$Volume,
     main = 'Dispersão: Circunferência vs Volume',
     xlab = 'Circunferência',
     ylab = 'Volume')
# Out:
# Plot with title “Dispersão: Circunferência vs Volume”

# %%
# adicionando personalizações
plot(trees$Girth, trees$Volume,
     main = "Dispersão: Circunferência vs Volume",
     xlab = 'Circunferência',
     ylab = 'Volume',
     col = 'blue',
     pch = 20)
# Out:
# Plot with title “Dispersão: Circunferência vs Volume”

# %%
# adicionando tremulação
plot(jitter(trees$Girth), trees$Volume,
     main = 'Dispersão com Tremulação',
     xlab = 'Circunferência',
     ylab = 'Volume',
     col = 'blue')
# Out:
# Plot with title “Dispersão com Tremulação”

# %%
# utilizando um atributo para cores
plot(CO2$conc, CO2$uptake,
     col = CO2$Treatment,
     pch = 20,
     main = 'Dispersão: Concentração vs Absorção de CO2')
# Out:
# Plot with title “Dispersão: Concentração vs Absorção de CO2”

# %%
# adicionando legendas
plot(CO2$conc, CO2$uptake,
     col = CO2$Treatment,
     pch = 20,
     main = 'Dispersão: Concentração vs Absorção de CO2')

legend('bottomright',
       legend = c('Non-chilled', 'Chilled'),
       fill = c('black', 'red'),
       title = 'Tratamento')
# Out:
# Plot with title “Dispersão: Concentração vs Absorção de CO2”

# %% [markdown]
# ### divisão de telas

# %%
# divisao em 4 partes 
split.screen(figs = c(2,2))

# 1
screen(1)
plot(trees$Girth, trees$Volume, main='Circunferência vs Volume')
# 2
screen(2)
plot(trees$Girth, trees$Height, main='Circunferência vs Altura')
# 3
screen(3)
plot(trees$Height, trees$Volume, main='Altura vs Volume')
# 4
screen(4)
hist(trees$Volume, main='Histograma do Volume')

close.screen(all=TRUE)
# Out:
# [1] 1 2 3 4
# Plot with title “Histograma do Volume”
